# %%
import numpy as np
import pandas as pd
scores=np.random.randint(50,101,size=(50,5))
stf=pd.DataFrame(scores,columns=['國文','英文','數學','地理','歷史'])
stf
# Out:
#     國文  英文   數學   地理   歷史
# 0   89  73   75   60   81
# 1   56  89   62   99   80
# 2   97  81   75   60   87
# 3   52  85   92   68   52
# 4   58  70   78   55   52
# 5   97  94   93   78   89
# 6   73  99   72   84   78
# 7   95  57   57   77   62
# 8   76  84   91   71   85
# 9   88  60   94   61  100
# 10  63  77   53   65   96
# 11  52  82   66   87   91
# 12  80  97   68   96   92
# 13  63  96   96   54   68
# 14  54  72   64   69   63
# 15  75  76   89   56   78
# 16  83  64   62   73   71
# 17  71  50   67   99   59
# 18  54  81   94  100   57
# 19  85  89   92   58   61
# 20  93  97   84   69   66
# 21  51  80   91   94   77
# 22  83  81   82   59   85
# 23  83  59   67   61   61
# 24  70  57   55   84   71
# 25  53  89   86   53   79
# 26  54  89   97   60   84
# 27  56  58  100   76   95
# 28  60  67   72   58   53
# 29  75  52   81   64   54
# 30  69  52   83   54   94
# 31  61  54   60   76   95
# 32  79  54   50   90   81
# 33  69  74   59   95   94
# ...
