# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df

# %%
from pandas import Series,DataFrame
def fun3(s:Series):
    sum=s.sum()
    mean=s.mean()
    count=s[s<60].count()
    values=s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])
student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數             不及格科目
# 魏秋萍  331  66.2     2          [數學, 地理]
# 林柏洋  347  69.4     2          [地理, 歷史]
# 王雅慧  376  75.2     0                []
# 劉萬季  411  82.2     0                []
# 吳振瑋  370  74.0     2          [國文, 歷史]
# 趙家豪  398  79.6     1              [國文]
# 陳怡容  418  83.6     0                []
# 楊少亮  411  82.2     0                []
# 孫火清  319  63.8     1              [數學]
# 陳嘉淑  420  84.0     0                []
# 羅佩樺  328  65.6     1              [數學]
# 王明昇  361  72.2     2          [國文, 歷史]
# 周琬婷  331  66.2     1              [國文]
# 梁柏宇  326  65.2     2          [數學, 地理]
# 林益妏  423  84.6     0                []
# 吳淑惠  400  80.0     0                []
# 劉雯芬  398  79.6     0                []
# 陳怡伶  415  83.0     0                []
# 魏秋萍  370  74.0     1              [地理]
# 陳信宏  391  78.2     1              [數學]
# 吳振瑋  348  69.6     2          [國文, 數學]
# 李淑芳  341  68.2     2          [國文, 歷史]
# 林思賢  432  86.4     0                []
# 鞠冠宇  400  80.0     0                []
# 蕭怡伶  384  76.8     0                []
# 謝哲維  344  68.8     2          [國文, 地理]
# 陳建香  403  80.6     0                []
# 高士凱  403  80.6     0                []
# 王泓泰  330  66.0     3      [國文, 英文, 地理]
# 陳彥治  338  67.6     2          [國文, 歷史]
# 林世城  336  67.2     3      [國文, 英文, 數學]
# 陳逸凡  378  75.6     2          [國文, 地理]
# 林清英  368  73.6     1              [國文]
# 葉志峰  302  60.4     4  [英文, 數學, 地理, 歷史]
# 林佳光  345  69.0     2          [國文, 地理]
# 詹忠光  359  71.8     1              [地理]
# 劉耿琦  395  79.0     1              [國文]
# 鞠冠宇  366  73.2     0                []
# 楊韻如  376  75.2     1              [國文]
# 張彥博  387  77.4     0                []
# 詹忠光  394  78.8     1              [國文]
# 洪奎夫  349  69.8     1              [歷史]
# 吳明妮  388  77.6     1              [歷史]
# 葉軍仰  342  68.4     2          [數學, 地理]
# 昌嘉洋  411  82.2     0                []
# 張凱妮  367  73.4     2          [國文, 英文]
# 白美珍  372  74.4     1              [數學]
# 張嘉韋  338  67.6     2          [國文, 歷史]
# 陳得映  389  77.8     0                []
# 張明惟  404  80.8     1              [歷史]
